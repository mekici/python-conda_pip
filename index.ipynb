# %% [markdown]
# # Aufgabe zur Datenvisualisierung
#
# ## Aufgabenstellung
# In dieser Aufgabe importierst Du einen Datensatz, filterst diesen für relevante Variablen und führst auf der Grundlage dieser eine Datenvisualisierung und Analyse der Normalverteilung durch.
#
# ### 1.) Import des Datensatzes
# Für dieser Aufgabe nehmen wir einen Datensatz, der direkt über einen Import aus dem Internet verfügbar ist und bei dem es sich um Daten aus dem Bildungskontext handelt, der sowohl kategoriale als auch numerische Variablen hat. Dazu nehmen wir einen fiktionalen Datensatz von Royce Kimmons, der Angaben zu einigen Hintergrundvariablen sowie Testergebnise in Lesen, Schreiben und Mathematik enthält. Dieser Datensatz ist auf Github im Ordner "Data" verfügbar.
#
# Aufgabe: Importieren Sie den Datensatz in eine Variable.

# %%
 data <- read.csv('/data/exams.csv', sep=",", header=TRUE)

# %%
data
# Out:
#     gender race.ethnicity parental.level.of.education lunch
# 1   female group D        some college                free/reduced
# 2   male   group D        associate's degree          standard
# 3   male   group C        high school                 free/reduced
# 4   female group B        bachelor's degree           standard
# 5   male   group E        bachelor's degree           standard
# 6   female group D        associate's degree          standard
# 7   female group A        high school                 free/reduced
# 8   female group E        high school                 standard
# 9   female group B        some college                standard
# 10  female group A        associate's degree          free/reduced
# 11  male   group A        associate's degree          standard
# 12  male   group B        some college                standard
# 13  female group A        master's degree             standard
# 14  female group C        some high school            standard
# ...

# %% [markdown]
# ### 2.) Reduzierung des Datensatzes
# In diesem Schritt haben Sie die Aufgabe, den Datensatz auf die Spalten "gender", "math.score", "reading.score" und "writing.score" zu reduzieren

# %% [markdown]
# ### 3.) Datenvisualisierung
# Da Sie nun den Datensatza auf das Notwendigste reduziert haben, sollen die Daten nun visualisiert werden. Schreiben Sie dazu nun Code, der
#
# 1.) Eine der drei Testdaten in einem Streudiagramm ausgibt.
# 2.) Eine der drei Testdaten in einem Boxplot ausgibt.
# 3.) Eine der drei Testdaten verteilt nach Gender in zwei Boxplots ausgibt.

# %% [markdown]
# 3.1) Streudiagramm

# %% [markdown]
# 3.2) Boxplot

# %% [markdown]
# 3.3) 2 Boxplots aufgeteilt nach Geschlecht

# %% [markdown]
# ### 4.) Überprüfung der Variablen auf Normalverteilung
# Um zu Übeprüfen, ob die numerischen Daten normal verteilt sind, führen Sie bitte
#
# 1.) die Visualisierung aller Testdaten über einen sog. QQ-Plot durch und
# 2.) nehmen Sie für diese Variablen einen Shapiro-Wilk-Test vor und beantworten Sie die Multiple-Choice-Fragen zur Normalverteilung.

# %% [markdown]
# 4.1) QQ-Plots

# %% [markdown]
# 4.2) Shapiro-Wilk-Test
